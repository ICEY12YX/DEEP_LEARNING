# %%
# 将外部数据导入到代码里存成DataFrame,然后进行分析,最后导出到外部文件

# 有不同导入导出函数,支持不同格式 read_xxx to_xxx

# 导入
# csv格式是最常用的文本格式,每行表示一条记录,每条记录由一个或多个字段组成,字段之间用逗号分隔
# 类似excel表格,但是没有表头,没有格式,没有公式,没有图表,没有宏,没有数据透视表,没有条件格式,没有数据验证,没有数据保护,没有数据连接,没有数据模型,没有数据分析工具,没有数据分析插件,没有数据分析功能,没有数据分析工具包,没有数据分析插件包,没有数据分析插件工具包....总之就是最纯粹的表格

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("student.csv")
print(data)
# 发现会自动加上索引(最左边的列)

# 中间处理,就和前面教的一样

data.to_pickle("student.pkl")  # 将DataFrame保存为pickle格式的文件
# pickle格式是Python特有的二进制格式,可以保存Python对象,包括DataFrame,Series,ndarray等,可以保存到文件中,也可以保存到内存中,可以保存到数据库中,可以保存到网络中等
# Out:
#          学号  姓名 性别  年龄      班级  语文  数学  英语   总分
# 0   2024001  张三  男  18  高一(1)班  92  88  95  275
# 1   2024002  李四  女  18  高一(1)班  85  96  78  259
# 2   2024003  王五  男  17  高一(2)班  78  85  92  255
# 3   2024004  赵六  女  18  高一(2)班  95  90  88  273
# 4   2024005  孙七  男  17  高一(1)班  62  55  70  187
# 5   2024006  周八  女  18  高一(3)班  88  92  85  265
# 6   2024007  吴九  男  17  高一(3)班  76  80  72  228
# 7   2024008  郑十  女  18  高一(2)班  91  87  94  272
# 8   2024009  冯一  男  17  高一(1)班  83  79  81  243
# 9   2024010  陈二  女  18  高一(3)班  90  93  96  279
# 10  2024011  褚三  男  17  高一(2)班  68  72  65  205
# 11  2024012  卫四  女  18  高一(1)班  94  91  89  274
