# %% [markdown]
# # print()

# %%
print(1)

# print(we're going to do something)
# SyntaxError: EOL while scanning string literal
# print(we)
# NameError: name 'we' is not defined
print("we're going to do something")
print("we")
# print('we're going to do something')
# SyntaxError: invalid syntax
print("we're going to do something")
print("we're going to do something")

print("fan" + "yuan")
# print('fan'+11)
# TypeError: can only concatenate str (not "int") to str
print("fan" + "11")
print("fan" + str(11))

print(1 + 2)
print("1+2")
print(int("1") + 2)
# print(int('1.2')+2)
# ValueError: invalid literal for int() with base 10: '1.2'
print(float("1.2") + 2)
# Out:
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 print(1)
#       3 # print(we're going to do something)
#       4 # SyntaxError: EOL while scanning string literal
# ----> 5 print(we)
#       6 print("we're going to do something")
#       7 print("we")
#
# NameError: name 'we' is not defined
