# %% [markdown]
# # while循环

# %%
condition = 1
while condition < 10:
    print(condition)
    condition = condition + 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
while True:
    print("I'm True")
