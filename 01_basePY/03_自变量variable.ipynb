# %% [markdown]
# # 自变量variable

# %%
fan = 1
print(fan)
# Out:
# 1
# 2 3 4
# 5 6 7
# 16

# %%
fan = 2
yuan = 3
xie = 4
print(fan, yuan, xie)
# Out:
# 2 3 4

# %%
fan, yuan, xie = 5, 6, 7
print(fan, yuan, xie)
# Out:
# 5 6 7

# %%
fan = 8
yuan = fan * 2
print(yuan)
# Out:
# 16
