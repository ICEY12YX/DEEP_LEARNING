# %% [markdown]
# # 自变量variable

# %%
fan = 1
print(fan)

fan = 2
yuan = 3
xie = 4
print(fan, yuan, xie)

fan, yuan, xie = 5, 6, 7
print(fan, yuan, xie)

fan = 8
yuan = fan * 2
print(yuan)
# Out:
# 1
# 2 3 4
# 5 6 7
# 16
