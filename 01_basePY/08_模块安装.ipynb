# %% [markdown]
# # 模块安装

# %%
# 为什么要py要进行模块安装? 模块安装就是指安装一些别人写好的代码, 这些代码可以帮助我们快速实现一些功能, 而不需要自己去写这些代码, 也就是节省时间和精力.
# 例如, 我们要进行图像处理, 我们可以安装一个叫做PIL的模块, 这个模块里面有很多函数可以帮助我们快速实现图像处理功能.
# 比如用下面这个命令
# sudo pip install Pillow  # 安装PIL模块
# 疑问 为什么加sudo? sudo是超级用户的意思, 在Linux系统中, 有些操作需要超级用户权限才能执行, 例如安装软件包, 修改系统配置等. 如果你没有超级用户权限, 那么你就不能执行这些操作. 但是在Windows系统中, 一般不需要加sudo, 因为Windows系统中没有超级用户的概念.

# 关于命令怎么写
# 关于怎么安装包的时候有什么规范要注意(但是这个应该没什么要注意的,就activate对应环境.然后pip或conda对应环包就好了)
# 这两个问题之后再考虑
